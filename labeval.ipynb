# %%
import pandas as pd
import numpy as np
import  matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
train = pd.read_parquet("train_data.csv")

# %%
train.head()
# Out:
#                    era data_type  feature_honoured_observational_balaamite  \
# id
# nb5b06e83fe1c412  0439     train                                         2
# na89cbf822b8badb  0329     train                                         4
# nfe7c4b2f97ee047  0287     train                                         2
# n3e103b605aff41f  0357     train                                         2
# nc4ac47de23c5039  0061     train                                         1
#
#                   feature_polaroid_vadose_quinze  \
# id
# nb5b06e83fe1c412                               3
# na89cbf822b8badb                               3
# nfe7c4b2f97ee047                               4
# n3e103b605aff41f                               4
# nc4ac47de23c5039                               1
#
#                   feature_untidy_withdrawn_bargeman  \
# id
# nb5b06e83fe1c412                                  3
# na89cbf822b8badb                                  4
# nfe7c4b2f97ee047                                  2
# n3e103b605aff41f                                  1
# nc4ac47de23c5039                                  3
#
#                   feature_genuine_kyphotic_trehala  \
# id
# nb5b06e83fe1c412                                 3
# na89cbf822b8badb                                 4
# nfe7c4b2f97ee047                                 3
# n3e103b605aff41f                                 1
# nc4ac47de23c5039                                 3
#
#                   feature_unenthralled_sportful_schoolhouse  \
# id
# nb5b06e83fe1c412                                          2
# na89cbf822b8badb                                          4
# nfe7c4b2f97ee047                                          1
# n3e103b605aff41f                                          0
# nc4ac47de23c5039                                          2
#
#                   feature_divulsive_explanatory_ideologue  \
# id
# nb5b06e83fe1c412                                        4
# na89cbf822b8badb                                        0
# nfe7c4b2f97ee047                                        3
# n3e103b605aff41f                                        1
# nc4ac47de23c5039                                        3
#
#                   feature_ichthyotic_roofed_yeshiva  \
# id
# nb5b06e83fe1c412                                  3
# na89cbf822b8badb                                  4
# nfe7c4b2f97ee047                                  1
# n3e103b605aff41f                                  1
# nc4ac47de23c5039                                  3
#
#                   feature_waggly_outlandish_carbonisation  ...    T0    T1  \
# id                                                         ...
# nb5b06e83fe1c412                                        1  ...  0.25  0.50
# na89cbf822b8badb                                        4  ...  0.00  0.00
# nfe7c4b2f97ee047                                        4  ...  0.75  0.75
# n3e103b605aff41f                                        4  ...  0.25  0.00
# nc4ac47de23c5039                                        2  ...  0.50  0.75
#
#                     T2    T3    T4    T5    T6    T7    T8    T9
# id
# nb5b06e83fe1c412  1.00  0.25  0.75  0.25  0.75  0.25  0.75  0.25
# na89cbf822b8badb  0.25  0.00  0.25  0.25  0.50  0.00  0.50  0.00
# nfe7c4b2f97ee047  0.75  1.00  0.75  0.75  0.50  1.00  0.75  0.75
# n3e103b605aff41f  0.50  0.50  0.50  0.25  0.50  0.25  0.25  0.25
# nc4ac47de23c5039  0.50  0.50  0.25  0.50  0.50  0.75  0.25  0.50
#
# [5 rows x 2388 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1936416 entries, nb5b06e83fe1c412 to n11b6347af31aa4f
# Columns: 2388 entries, era to T9
# dtypes: float32(10), int8(2376), object(2)
# memory usage: 4.4+ GB

# %%
type(train)
# Out:
# pandas.core.frame.DataFrame

# %%
trainone = train.drop(columns="data_type")

# %%
type(trainone)
# Out:
# pandas.core.frame.DataFrame

# %%
trainone.drop(columns=["T1", "T2", "T3", "T5", "T6", "T7", "T8", "T9"], inplace=True)

# %%
type(trainone)
# Out:
# pandas.core.frame.DataFrame

# %%
trainone.head()
# Out:
#                    era  feature_honoured_observational_balaamite  \
# id
# nb5b06e83fe1c412  0439                                         2
# na89cbf822b8badb  0329                                         4
# nfe7c4b2f97ee047  0287                                         2
# n3e103b605aff41f  0357                                         2
# nc4ac47de23c5039  0061                                         1
#
#                   feature_polaroid_vadose_quinze  \
# id
# nb5b06e83fe1c412                               3
# na89cbf822b8badb                               3
# nfe7c4b2f97ee047                               4
# n3e103b605aff41f                               4
# nc4ac47de23c5039                               1
#
#                   feature_untidy_withdrawn_bargeman  \
# id
# nb5b06e83fe1c412                                  3
# na89cbf822b8badb                                  4
# nfe7c4b2f97ee047                                  2
# n3e103b605aff41f                                  1
# nc4ac47de23c5039                                  3
#
#                   feature_genuine_kyphotic_trehala  \
# id
# nb5b06e83fe1c412                                 3
# na89cbf822b8badb                                 4
# nfe7c4b2f97ee047                                 3
# n3e103b605aff41f                                 1
# nc4ac47de23c5039                                 3
#
#                   feature_unenthralled_sportful_schoolhouse  \
# id
# nb5b06e83fe1c412                                          2
# na89cbf822b8badb                                          4
# nfe7c4b2f97ee047                                          1
# n3e103b605aff41f                                          0
# nc4ac47de23c5039                                          2
#
#                   feature_divulsive_explanatory_ideologue  \
# id
# nb5b06e83fe1c412                                        4
# na89cbf822b8badb                                        0
# nfe7c4b2f97ee047                                        3
# n3e103b605aff41f                                        1
# nc4ac47de23c5039                                        3
#
#                   feature_ichthyotic_roofed_yeshiva  \
# id
# nb5b06e83fe1c412                                  3
# na89cbf822b8badb                                  4
# nfe7c4b2f97ee047                                  1
# n3e103b605aff41f                                  1
# nc4ac47de23c5039                                  3
#
#                   feature_waggly_outlandish_carbonisation  \
# id
# nb5b06e83fe1c412                                        1
# na89cbf822b8badb                                        4
# nfe7c4b2f97ee047                                        4
# n3e103b605aff41f                                        4
# nc4ac47de23c5039                                        2
#
#                   feature_floriated_amish_sprite  ...  \
# id                                                ...
# nb5b06e83fe1c412                               1  ...
# na89cbf822b8badb                               0  ...
# nfe7c4b2f97ee047                               0  ...
# n3e103b605aff41f                               2  ...
# nc4ac47de23c5039                               2  ...
#
#                   feature_waiting_torn_alexia  feature_hemal_outright_panicle  \
# id
# nb5b06e83fe1c412                            4                               4
# na89cbf822b8badb                            2                               2
# nfe7c4b2f97ee047                            4                               0
# n3e103b605aff41f                            2                               2
# nc4ac47de23c5039                            4                               4
#
#                   feature_septuagenary_bully_puna  \
# id
# nb5b06e83fe1c412                                0
# na89cbf822b8badb                                2
# nfe7c4b2f97ee047                                4
# n3e103b605aff41f                                2
# nc4ac47de23c5039                                4
#
#                   feature_ovoid_group_tellurian  \
# id
# nb5b06e83fe1c412                              0
# na89cbf822b8badb                              2
# nfe7c4b2f97ee047                              0
# n3e103b605aff41f                              2
# nc4ac47de23c5039                              4
#
#                   feature_crankier_stupefied_bailsman  \
# id
# nb5b06e83fe1c412                                    0
# na89cbf822b8badb                                    2
# nfe7c4b2f97ee047                                    3
# n3e103b605aff41f                                    2
# nc4ac47de23c5039                                    4
#
#                   feature_vizirial_bespangled_pteridophyte  \
# id
# nb5b06e83fe1c412                                         0
# na89cbf822b8badb                                         2
# nfe7c4b2f97ee047                                         3
# n3e103b605aff41f                                         2
# nc4ac47de23c5039                                         4
#
#                   feature_interventionist_gambling_osteomalacia  \
# id
# nb5b06e83fe1c412                                              0
# na89cbf822b8badb                                              2
# nfe7c4b2f97ee047                                              4
# n3e103b605aff41f                                              2
# nc4ac47de23c5039                                              4
#
#                   feature_unnameable_unphonetic_conniver    T0    T4
# id
# nb5b06e83fe1c412                                       0  0.25  0.75
# na89cbf822b8badb                                       2  0.00  0.25
# nfe7c4b2f97ee047                                       0  0.75  0.75
# n3e103b605aff41f                                       2  0.25  0.50
# nc4ac47de23c5039                                       4  0.50  0.25
#
# [5 rows x 2379 columns]

# %%
type(trainone)
# Out:
# pandas.core.frame.DataFrame
