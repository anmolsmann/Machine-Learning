# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import pandas as pd
import pyarrow.parquet as pq
import lightgbm as lgbm

# %%
train = pd.read_parquet('train_data.parquet')
test = pd.read_parquet('test_data.parquet')

# %%
col=['T0','T1','T2','T3','T5','T6','T7','T8','T9','era','data_type']
train = train.drop(columns=col)

# %%
finalSub = pd.DataFrame()
finalSub['ID'] = test.index
columnNames=['era','data_type']
test = test.drop(columns=columnNames)

# %%
submission_df

# %%
# Copy the values of 'T1' predictions from submission_df to submission
submission['T3'] = submission_df['T3']

# %%
# Save the submission DataFrame to a CSV file
submission.to_csv('submission.csv', index=False)
